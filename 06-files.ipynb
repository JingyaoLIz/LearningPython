# %% [markdown]
# ## Multiple Files

# %%
import glob

print(glob.glob('data/inflammation*.csv'))  # names match a pattern
# Out:
# ['data\\inflammation-01.csv', 'data\\inflammation-02.csv', 'data\\inflammation-03.csv', 'data\\inflammation-04.csv', 'data\\inflammation-05.csv', 'data\\inflammation-06.csv', 'data\\inflammation-07.csv', 'data\\inflammation-08.csv', 'data\\inflammation-09.csv', 'data\\inflammation-10.csv', 'data\\inflammation-11.csv', 'data\\inflammation-12.csv']

# %%
import numpy
import matplotlib.pyplot

filenames = sorted(glob.glob('data/inflammation*.csv'))
filenames = filenames[0:3]
for filename in filenames:
    print(filename)

    data = numpy.loadtxt(fname=filename, delimiter=',')  # load data

    fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

    axes1 = fig.add_subplot(1, 3, 1)
    axes2 = fig.add_subplot(1, 3, 2)
    axes3 = fig.add_subplot(1, 3, 3)

    axes1.set_ylabel('average')
    axes1.plot(numpy.mean(data, axis=0))

    axes2.set_ylabel('max')
    axes2.plot(numpy.max(data, axis=0))

    axes3.set_ylabel('min')
    axes3.plot(numpy.min(data, axis=0))

    fig.tight_layout()
    matplotlib.pyplot.show()
# Out:
# data\inflammation-01.csv
# data\inflammation-02.csv
# data\inflammation-03.csv

# %%
filenames = filenames[0:2]
diff_avarage = [[0],[0]]
for idx, filename in enumerate(filenames):
    print(filename)

    data = numpy.loadtxt(fname=filename, delimiter=',')  # load data
    diff_avarage [idx] = numpy.mean(data, axis = 0);

fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

matplotlib.pyplot.ylabel('Difference in average')
matplotlib.pyplot.plot(diff_avarage [1] - diff_avarage [0])

fig.tight_layout()
matplotlib.pyplot.show()
# Out:
# data\inflammation-01.csv
# data\inflammation-02.csv

# %%
filenames = glob.glob('data/inflammation*.csv')
composite_data = numpy.zeros((60,40))
max_pa = []
min_pa = []
average = [0]
idx = 0
for filename in filenames:
    data = numpy.loadtxt(fname=filename, delimiter=',')  # load data
    # sum each new file's data into composite_data as it's read
    max_pa.append(data.max(axis = 0))
    min_pa.append(data.min(axis = 0))
    average = average + data.mean(axis = 0)
    idx = idx + 1
    
# and then divide the composite_data by number of samples
composite_data = composite_data / len(filenames)

fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

axes1 = fig.add_subplot(1, 3, 1)
axes2 = fig.add_subplot(1, 3, 2)
axes3 = fig.add_subplot(1, 3, 3)

axes1.set_ylabel('average')
axes1.plot(average/idx)
# print(average)

axes2.set_ylabel('max')
axes2.plot(numpy.max(max_pa, axis=0))
# print(max_pa)

axes3.set_ylabel('min')
axes3.plot(numpy.min(min_pa, axis=0))
# print(min_pa)

fig.tight_layout()
matplotlib.pyplot.show()

# %%
filenames = glob.glob('data/inflammation*.csv')
composite_data = numpy.zeros((60,40))

for filename in filenames:
    data = numpy.loadtxt(fname = filename, delimiter=',')
    composite_data = composite_data + data

composite_data = composite_data / len(filenames)
print(len(filenames))
print(composite_data)

fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

axes1 = fig.add_subplot(1, 3, 1)
axes2 = fig.add_subplot(1, 3, 2)
axes3 = fig.add_subplot(1, 3, 3)

axes1.set_ylabel('average')
axes1.plot(numpy.mean(composite_data, axis=0))

axes2.set_ylabel('max')
axes2.plot(numpy.max(composite_data, axis=0))

axes3.set_ylabel('min')
axes3.plot(numpy.min(composite_data, axis=0))

fig.tight_layout()

matplotlib.pyplot.show()
# Out:
# 12
# [[0.         0.33333333 0.58333333 ... 1.16666667 0.66666667 0.33333333]
#  [0.         0.58333333 0.66666667 ... 1.16666667 0.5        0.41666667]
#  [0.         0.5        1.08333333 ... 0.75       0.75       0.58333333]
#  ...
#  [0.         0.33333333 1.5        ... 1.33333333 0.91666667 0.41666667]
#  [0.         0.33333333 0.75       ... 1.08333333 0.75       0.41666667]
#  [0.         0.16666667 0.91666667 ... 1.5        0.58333333 0.41666667]]
